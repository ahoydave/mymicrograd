# %%
from nn import Value, draw_dot

# %%
x = Value(4, label='x')
y = Value(2, label='y')
f = x.sq() + y
f.grad = 1.0
f.backprop()
draw_dot(f)

# %%
x = Value(2, label='x')
f = x * x; f.label = 'f'
f.grad = 1.0
f.backprop()
draw_dot(f)

# %%
x = Value(2, label='x')
f = x.sq(); f.label = 'f'
f.grad = 1.0
f.backprop()
draw_dot(f)
